# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a data set which contains information World cup matches. Let's use the pandas commands learned in the previous lecture to learn more about our data!

# %% [markdown]
# ## Objectives
# You will be able to:
# * Understand and explain some key Pandas methods
# * Access DataFrame data by using the label
# * Perform boolean indexing on both Series and DataFrames
# * Use simple selectors for series
# * Set new Series and DataFrame inputs

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load the file `WorldCupMatches.csv` as a dataframe in Pandas

# %%
import pandas as pd

# %%
data = pd.read_csv('WorldCupMatches.csv')
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
# Year                    852 non-null float64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null float64
# Away Team Goals         852 non-null float64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null float64
# Half-time Away Goals    852 non-null float64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null float64
# MatchID                 852 non-null float64
# Home Team Initials      852 non-null object
# Away Team Initials      852 non-null object
# dtypes: float64(8), object(12)
# memory usage: 714.5+ KB

# %% [markdown]
# ## Common methods and attributes

# %% [markdown]
# Use the correct method to look at the first 7 rows of the data set.

# %%
df.iloc[0:7]
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930.0  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930.0  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
# 5          Chile              3.0              0.0         Mexico
# 6     Yugoslavia              4.0              0.0        Bolivia
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
# 2                    24059.0                   2.0                   0.0
# 3                     2549.0                   1.0                   0.0
# 4                    23409.0                   0.0                   0.0
# 5                     9249.0                   1.0                   0.0
# 6                    18306.0                   0.0                   0.0
#
#                     Referee               Assistant 1  \
# 0    LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)    LOMBARDI Domingo (URU)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)    201.0   1096.0                FRA
# 1       WARNKEN Alberto (CHI)    201.0   1090.0                USA
# 2         BALWAY Thomas (FRA)    201.0   1093.0                YUG
# 3    MATEUCCI Francisco (URU)    201.0   1098.0                ROU
# 4  RADULESCU Constantin (ROU)    201.0   1085.0                ARG
# 5         LANGENUS Jean (BEL)    201.0   1095.0                CHI
# 6       WARNKEN Alberto (CHI)    201.0   1092.0                YUG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA
# 5                MEX
# 6                BOL

# %% [markdown]
# Look at the last 3 rows of the data set.

# %%
df.tail(3)
# Out:
#       Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 4569   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4570   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4571   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#       Away Team Goals Away Team Name Win conditions  Attendance  \
# 4569              NaN            NaN            NaN         NaN
# 4570              NaN            NaN            NaN         NaN
# 4571              NaN            NaN            NaN         NaN
#
#       Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 4569                   NaN                   NaN     NaN         NaN
# 4570                   NaN                   NaN     NaN         NaN
# 4571                   NaN                   NaN     NaN         NaN
#
#      Assistant 2  RoundID  MatchID Home Team Initials Away Team Initials
# 4569         NaN      NaN      NaN                NaN                NaN
# 4570         NaN      NaN      NaN                NaN                NaN
# 4571         NaN      NaN      NaN                NaN                NaN

# %% [markdown]
# Get a concise summary of your data using `.info()`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
# Year                    852 non-null float64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null float64
# Away Team Goals         852 non-null float64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null float64
# Half-time Away Goals    852 non-null float64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null float64
# MatchID                 852 non-null float64
# Home Team Initials      852 non-null object
# Away Team Initials      852 non-null object
# dtypes: float64(8), object(12)
# memory usage: 714.5+ KB

# %% [markdown]
# Obtain a tuple representing the number of rows and number of columns

# %%
df.shape
# Out:
# (4572, 20)

# %% [markdown]
# Use the appropriate attribute to get the column names

# %%
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# ## Selecting dataframe information

# %% [markdown]
# When looking at the dataframe's `.head()`, you might have noticed that the games are structured chronologically in the dataframe.
#
# Use the right selection method to print all the information from the 3rd to the 5th game.

# %%
df.iloc[2:5]
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 2                    24059.0                   2.0                   0.0
# 3                     2549.0                   1.0                   0.0
# 4                    23409.0                   0.0                   0.0
#
#                  Referee              Assistant 1                 Assistant 2  \
# 2    TEJADA Anibal (URU)  VALLARINO Ricardo (URU)         BALWAY Thomas (FRA)
# 3  WARNKEN Alberto (CHI)      LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)
# 4    REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 2    201.0   1093.0                YUG                BRA
# 3    201.0   1098.0                ROU                PER
# 4    201.0   1085.0                ARG                FRA

# %% [markdown]
# Now, print all the info from game 5-9, but we're only interested to print out the "Home Team Name" and the "Away Team Name",

# %%
df.loc[4:9,["Home Team Name","Away Team Name"]]
# Out:
#   Home Team Name Away Team Name
# 4      Argentina         France
# 5          Chile         Mexico
# 6     Yugoslavia        Bolivia
# 7            USA       Paraguay
# 8        Uruguay           Peru
# 9          Chile         France

# %% [markdown]
# Next, we'd like the information on all the games played in Group 3 for the 1950 World Cup.

# %%
df.loc[(df['Stage']=='Group 3')&(df['Year']==1950.0)]
# Out:
#       Year              Datetime    Stage           Stadium        City  \
# 56  1950.0  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950.0  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950.0  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden              3.0              2.0          Italy
# 61         Sweden              2.0              2.0       Paraguay
# 65          Italy              2.0              0.0       Paraguay
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 56                    36502.0                   2.0                   1.0
# 61                     7903.0                   2.0                   1.0
# 65                    25811.0                   1.0                   0.0
#
#                   Referee             Assistant 1                Assistant 2  \
# 56        LUTZ Jean (SUI)     BERANEK Alois (AUT)        TEJADA Carlos (MEX)
# 61  MITCHELL Robert (SCO)       LEMESIC Leo (YUG)     GARCIA Prudencio (USA)
# 65     ELLIS Arthur (ENG)  GARCIA Prudencio (USA)  DE LA SALLE Charles (FRA)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 56    208.0   1219.0                SWE                ITA
# 61    208.0   1228.0                SWE                PAR
# 65    208.0   1218.0                ITA                PAR

# %% [markdown]
# Let's repeat the command above, but now we only want to print out the attendance colum for the Group 3 games

# %% [markdown]
# You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %%
df.loc[(df['Stage']=='Group 3')&(df['Year']==1950.0),['Attendance']]
# Out:
#     Attendance
# 56     36502.0
# 61      7903.0
# 65     25811.0

# %% [markdown]
# Throughout the entire history of the world cup, How many Home games were played by the Netherlands?

# %%
df.loc[df['Home Team Name']=='Netherlands']
# Out:
#        Year               Datetime                  Stage  \
# 244  1974.0   19 Jun 1974 - 19:30                 Group 3
# 258  1974.0   26 Jun 1974 - 19:30                 Group A
# 265  1974.0   03 Jul 1974 - 19:30                 Group A
# 269  1974.0  07 July 1974 - 16:00                   Final
# 277  1978.0   03 Jun 1978 - 16:45                 Group 4
# 285  1978.0   07 Jun 1978 - 16:45                 Group 4
# 295  1978.0   14 Jun 1978 - 13:45                 Group A
# 302  1978.0   21 Jun 1978 - 13:45                 Group A
# 422  1990.0   12 Jun 1990 - 21:00                 Group F
# 472  1994.0   20 Jun 1994 - 19:30                 Group F
# 504  1994.0   04 Jul 1994 - 12:00             Round of 16
# 509  1994.0   09 Jul 1994 - 14:30          Quarter-finals
# 525  1998.0   13 Jun 1998 - 21:00                 Group E
# 542  1998.0   20 Jun 1998 - 21:00                 Group E
# 557  1998.0   25 Jun 1998 - 16:00                 Group E
# 569  1998.0   29 Jun 1998 - 21:00             Round of 16
# 574  1998.0   04 Jul 1998 - 16:30          Quarter-finals
# 578  1998.0   11 Jul 1998 - 21:00   Match for third place
# 665  2006.0   16 Jun 2006 - 18:00                 Group C
# 682  2006.0   21 Jun 2006 - 21:00                 Group C
# 716  2010.0   14 Jun 2010 - 13:30                 Group E
# 731  2010.0   19 Jun 2010 - 13:30                 Group E
# 760  2010.0   28 Jun 2010 - 16:00             Round of 16
# 764  2010.0   02 Jul 2010 - 16:00          Quarter-finals
# 771  2010.0   11 Jul 2010 - 20:30                   Final
# 805  2014.0   23 Jun 2014 - 13:00                 Group B
# 829  2014.0   09 Jul 2014 - 17:00             Semi-finals
# 830  2014.0   05 Jul 2014 - 17:00          Quarter-finals
# 832  2014.0   29 Jun 2014 - 13:00             Round of 16
# 838  2014.0   29 Jun 2014 - 13:00             Round of 16
# 847  2014.0   05 Jul 2014 - 17:00          Quarter-finals
# 849  2014.0   09 Jul 2014 - 17:00             Semi-finals
#
#                                                Stadium  \
# 244                                   Westfalenstadion
# 258                                        Parkstadion
# 265                                   Westfalenstadion
# 269                                     Olympiastadion
# 277                                         San Martin
# 285                                         San Martin
# 295                  Estadio Ol�mpico Chateau Carreras
# 302  El Monumental - Estadio Monumental Antonio Ves...
# 422                                     Della Favorita
# 472                                        RFK Stadium
# 504                                        Citrus Bowl
# 509                                        Cotton Bowl
# 525                                    Stade de France
# 542                                    Stade V�lodrome
# 557                            Stade Geoffroy Guichard
# 569                                    Stade Municipal
# 574                                    Stade V�lodrome
# 578                                   Parc des Princes
# 665                           Gottlieb-Daimler-Stadion
# 682                  FIFA World Cup Stadium, Frankfurt
# 716                                Soccer City Stadium
# 731                                     Durban Stadium
# 760                                     Durban Stadium
# 764                             Port Elizabeth Stadium
# 771                                Soccer City Stadium
# 805                                 Arena de Sao Paulo
# 829                                 Arena de Sao Paulo
# 830                                   Arena Fonte Nova
# 832                                   Estadio Castelao
# 838                                   Estadio Castelao
# 847                                   Arena Fonte Nova
# 849                                 Arena de Sao Paulo
#
#                                    City Home Team Name  Home Team Goals  \
# 244                           Dortmund     Netherlands              0.0
# 258                      Gelsenkirchen     Netherlands              4.0
# 265                           Dortmund     Netherlands              2.0
# 269                             Munich     Netherlands              1.0
# 277                            Mendoza     Netherlands              3.0
# 285                            Mendoza     Netherlands              0.0
# 295                            Cordoba     Netherlands              5.0
# 302                       Buenos Aires     Netherlands              2.0
# 422                            Palermo     Netherlands              1.0
# 472                      Washington Dc     Netherlands              2.0
# 504                            Orlando     Netherlands              2.0
# 509                             Dallas     Netherlands              2.0
# 525                        Saint-Denis     Netherlands              0.0
# 542                         Marseilles     Netherlands              5.0
# 557                      Saint-Etienne     Netherlands              2.0
# 569                           Toulouse     Netherlands              2.0
# 574                         Marseilles     Netherlands              2.0
# 578                              Paris     Netherlands              1.0
# 665                          Stuttgart     Netherlands              2.0
# 682                     Frankfurt/Main     Netherlands              0.0
# 716                       Johannesburg     Netherlands              2.0
# 731                             Durban     Netherlands              1.0
# 760                             Durban     Netherlands              2.0
# 764  Nelson Mandela Bay/Port Elizabeth     Netherlands              2.0
# 771                       Johannesburg     Netherlands              0.0
# 805                          Sao Paulo     Netherlands              2.0
# 829                          Sao Paulo     Netherlands              0.0
# 830                           Salvador     Netherlands              0.0
# 832                          Fortaleza     Netherlands              2.0
# 838                          Fortaleza     Netherlands              2.0
# 847                           Salvador     Netherlands              0.0
# 849                          Sao Paulo     Netherlands              0.0
#
#      Away Team Goals           Away Team Name  \
# 244              0.0                   Sweden
# 258              0.0                Argentina
# 265              0.0                   Brazil
# 269              2.0               Germany FR
# 277              0.0                  IR Iran
# 285              0.0                     Peru
# 295              1.0                  Austria
# 302              1.0                    Italy
# 422              1.0                    Egypt
# 472              1.0             Saudi Arabia
# 504              0.0  rn">Republic of Ireland
# 509              3.0                   Brazil
# 525              0.0                  Belgium
# 542              0.0           Korea Republic
# 557              2.0                   Mexico
# 569              1.0               Yugoslavia
# 574              1.0                Argentina
# 578              2.0                  Croatia
# 665              1.0            C�te d'Ivoire
# 682              0.0                Argentina
# 716              0.0                  Denmark
# 731              0.0                    Japan
# 760              1.0                 Slovakia
# 764              1.0                   Brazil
# 771              1.0                    Spain
# 805              0.0                    Chile
# 829              0.0                Argentina
# 830              0.0               Costa Rica
# 832              1.0                   Mexico
# 838              1.0                   Mexico
# 847              0.0               Costa Rica
# 849              0.0                Argentina
#
#                             Win conditions    ...     Half-time Away Goals  \
# 244                                           ...                      0.0
# 258                                           ...                      0.0
# 265                                           ...                      0.0
# 269                                           ...                      2.0
# 277                                           ...                      0.0
# 285                                           ...                      0.0
# 295                                           ...                      0.0
# 302                                           ...                      1.0
# 422                                           ...                      0.0
# 472                                           ...                      1.0
# 504                                           ...                      0.0
# 509                                           ...                      0.0
# 525                                           ...                      0.0
# 542                                           ...                      0.0
# 557                                           ...                      0.0
# 569                                           ...                      0.0
# 574                                           ...                      1.0
# 578                                           ...                      2.0
# 665                                           ...                      1.0
# 682                                           ...                      0.0
# 716                                           ...                      0.0
# 731                                           ...                      0.0
# 760                                           ...                      0.0
# 764                                           ...                      1.0
# 771            Spain win after extra time     ...                      0.0
# 805                                           ...                      0.0
# 829    Argentina win on penalties (2 - 4)     ...                      0.0
# 830  Netherlands win on penalties (4 - 3)     ...                      0.0
# 832                                           ...                      0.0
# 838                                           ...                      0.0
# 847  Netherlands win on penalties (4 - 3)     ...                      0.0
# 849    Argentina win on penalties (2 - 4)     ...                      0.0
#
#                               Referee                         Assistant 1  \
# 244            WINSEMANN Werner (CAN)              TSCHENSCHER Kurt (GER)
# 258                DAVIDSON Bob (SCO)              TSCHENSCHER Kurt (GER)
# 265            TSCHENSCHER Kurt (GER)                  DAVIDSON Bob (SCO)
# 269                 TAYLOR John (ENG)    GONZALEZ ARCHUNDIA Alfonso (MEX)
# 277  GONZALEZ ARCHUNDIA Alfonso (MEX)                  WURTZ Robert (FRA)
# 285                PROKOP Adolf (GDR)       COEREZZA Norberto Angel (ARG)
# 295                 GORDON John (SCO)      ITHURRALDE Arturo Andres (ARG)
# 302              MARTINEZ Angel (ESP)                PESTARINO Luis (ARG)
# 422      SORIANO ALADREN Emilio (ESP)        CODESAL MENDEZ Edgardo (MEX)
# 472            DIAZ VEGA Manuel (ESP)               IVANOV Valentin (RUS)
# 504             MIKKELSEN Peter (DEN)                DUNSTER Gordon (AUS)
# 509             BADILLA Rodrigo (CRC)     AL GHATTAN Yousif Abdulla (BAH)
# 525           COLLINA Pierluigi (ITA)                MAZZEI Gennaro (ITA)
# 542              WOJCIK Ryszard (POL)               POCIEGIEL Jacek (POL)
# 557          ALZEID Abdulrahman (KSA)       TRESACO GRACIA Fernando (ESP)
# 569    GARCIA ARANDA Jose Maria (ESP)                RAUSIS Laurent (SUI)
# 574        BRIZIO CARTER Arturo (MEX)                   POWELL Owen (JAM)
# 578    GONZALEZ CHAVEZ Epifanio (PAR)                ZAMMIT Emanuel (MLT)
# 665                  RUIZ Oscar (COL)               TAMAYO Fernando (ECU)
# 682       MEDINA CANTALEJO Luis (ESP)  GIRALDEZ CARRASCO Victoriano (ESP)
# 716             St�phane LANNOY (FRA)                 DANSAULT Eric (FRA)
# 731             BALDASSI Hector (ARG)                 CASAS Ricardo (ARG)
# 760    Alberto UNDIANO MALLENCO (ESP)               MARTINEZ Fermin (ESP)
# 764            NISHIMURA Yuichi (JPN)                   SAGARA Toru (JPN)
# 771                 WEBB Howard (ENG)                   Darren CANN (ENG)
# 805              Bakary GASSAMA (GAM)            MENKOUANDE Evarist (CMR)
# 829                C�neyt �AKIR (TUR)                DURAN Bahattin (TUR)
# 830             Ravshan IRMATOV (UZB)         RASULOV Abduxamidullo (UZB)
# 832               PROENCA Pedro (POR)               MIRANDA Bertino (POR)
# 838               PROENCA Pedro (POR)               MIRANDA Bertino (POR)
# 847             Ravshan IRMATOV (UZB)         RASULOV Abduxamidullo (UZB)
# 849                C�neyt �AKIR (TUR)                DURAN Bahattin (TUR)
#
#                               Assistant 2     RoundID      MatchID  \
# 244                    THOMAS Clive (WAL)       262.0       2097.0
# 258                   KAZAKOV Pavel (URS)       263.0       1948.0
# 265                  SUPPIAH George (SIN)       263.0       1983.0
# 269              BARRETO RUIZ Ramon (URU)       605.0       2063.0
# 277                 COMESANA Miguel (ARG)       278.0       2388.0
# 285                  IVANOV Anatoly (URS)       278.0       2394.0
# 295                    BOUZO Farouk (SYR)       279.0       2220.0
# 302           OROZCO GUERRERO Cesar (PER)       279.0       2391.0
# 422  CARDELLINO DE SAN VICENTE Juan (URU)       322.0        151.0
# 472                   MARTON Sandor (HUN)       337.0       3058.0
# 504                 BRAZZALE Eugene (AUS)       338.0       3089.0
# 509                 FANAEI Mohammad (IRN)       796.0       3098.0
# 525                  ZAMMIT Emanuel (MLT)      1014.0       8733.0
# 542                    DUPANOV Yuri (BLR)      1014.0       8749.0
# 557              GHADANFARI Hussain (KUW)      1014.0       8766.0
# 569              GRIGORESCU Nicolae (ROU)      1024.0       8778.0
# 574                SALINAS Reynaldo (HON)      1025.0       8784.0
# 578                     FRED Lencie (VAN)      1028.0       8787.0
# 665                      NAVIA Jose (COL)  97410100.0   97410022.0
# 682          MEDINA HERNANDEZ Pedro (ESP)  97410100.0   97410037.0
# 716                     UGO Laurent (FRA)    249722.0  300061478.0
# 731                  MAIDANA Hernan (ARG)    249722.0  300111117.0
# 760                      YUSTE Juan (ESP)    249717.0  300111113.0
# 764                  JEONG Hae Sang (KOR)    249718.0  300061507.0
# 771               MULLARKEY Michael (ENG)    249721.0  300061509.0
# 805                KABANDA Felicien (RWA)    255931.0  300186470.0
# 829                     ONGUN Tarik (TUR)    255955.0  300186490.0
# 830              KOCHKAROV Bakhadyr (KGZ)    255953.0  300186488.0
# 832                      TRIGO Jose (POR)    255951.0  300186508.0
# 838                      TRIGO Jose (POR)    255951.0  300186508.0
# 847              KOCHKAROV Bakhadyr (KGZ)    255953.0  300186488.0
# 849                     ONGUN Tarik (TUR)    255955.0  300186490.0
#
#      Home Team Initials  Away Team Initials Played in ND ND Played
# 244                 NED                 SWE           ND       Yes
# 258                 NED                 ARG           ND       Yes
# 265                 NED                 BRA           ND       Yes
# 269                 NED                 FRG           ND       Yes
# 277                 NED                 IRN           ND       Yes
# 285                 NED                 PER           ND       Yes
# 295                 NED                 AUT           ND       Yes
# 302                 NED                 ITA           ND       Yes
# 422                 NED                 EGY           ND       Yes
# 472                 NED                 KSA           ND       Yes
# 504                 NED                 IRL           ND       Yes
# 509                 NED                 BRA           ND       Yes
# 525                 NED                 BEL           ND       Yes
# 542                 NED                 KOR           ND       Yes
# 557                 NED                 MEX           ND       Yes
# 569                 NED                 YUG           ND       Yes
# 574                 NED                 ARG           ND       Yes
# 578                 NED                 CRO           ND       Yes
# 665                 NED                 CIV           ND       Yes
# 682                 NED                 ARG           ND       Yes
# 716                 NED                 DEN           ND       Yes
# 731                 NED                 JPN           ND       Yes
# 760                 NED                 SVK           ND       Yes
# 764                 NED                 BRA           ND       Yes
# 771                 NED                 ESP           ND       Yes
# 805                 NED                 CHI           ND       Yes
# 829                 NED                 ARG           ND       Yes
# 830                 NED                 CRC           ND       Yes
# 832                 NED                 MEX           ND       Yes
# 838                 NED                 MEX           ND       Yes
# 847                 NED                 CRC           ND       Yes
# 849                 NED                 ARG           ND       Yes
#
# [32 rows x 22 columns]

# %% [markdown]
# How many games were playes by the Netherlands in total?

# %%
df.loc[(df['Home Team Name']=='Netherlands')| (df['Away Team Name']=='Netherlands')]
# Out:
#        Year               Datetime                     Stage  \
# 20   1934.0   27 May 1934 - 16:30          Preliminary round
# 41   1938.0   05 Jun 1938 - 18:30                First round
# 236  1974.0   15 Jun 1974 - 16:00                    Group 3
# 244  1974.0   19 Jun 1974 - 19:30                    Group 3
# 252  1974.0   23 Jun 1974 - 16:00                    Group 3
# 258  1974.0   26 Jun 1974 - 19:30                    Group A
# 262  1974.0   30 Jun 1974 - 16:00                    Group A
# 265  1974.0   03 Jul 1974 - 19:30                    Group A
# 269  1974.0  07 July 1974 - 16:00                      Final
# 277  1978.0   03 Jun 1978 - 16:45                    Group 4
# 285  1978.0   07 Jun 1978 - 16:45                    Group 4
# 293  1978.0   11 Jun 1978 - 16:45                    Group 4
# 295  1978.0   14 Jun 1978 - 13:45                    Group A
# 300  1978.0   18 Jun 1978 - 16:45                    Group A
# 302  1978.0   21 Jun 1978 - 13:45                    Group A
# 307  1978.0   25 Jun 1978 - 15:00                      Final
# 422  1990.0   12 Jun 1990 - 21:00                    Group F
# 432  1990.0   16 Jun 1990 - 21:00                    Group F
# 446  1990.0   21 Jun 1990 - 21:00                    Group F
# 451  1990.0   24 Jun 1990 - 21:00                Round of 16
# 472  1994.0   20 Jun 1994 - 19:30                    Group F
# 484  1994.0   25 Jun 1994 - 12:30                    Group F
# 496  1994.0   29 Jun 1994 - 12:30                    Group F
# 504  1994.0   04 Jul 1994 - 12:00                Round of 16
# 509  1994.0   09 Jul 1994 - 14:30             Quarter-finals
# 525  1998.0   13 Jun 1998 - 21:00                    Group E
# 542  1998.0   20 Jun 1998 - 21:00                    Group E
# 557  1998.0   25 Jun 1998 - 16:00                    Group E
# 569  1998.0   29 Jun 1998 - 21:00                Round of 16
# 574  1998.0   04 Jul 1998 - 16:30             Quarter-finals
# 576  1998.0   07 Jul 1998 - 21:00                Semi-finals
# 578  1998.0   11 Jul 1998 - 21:00      Match for third place
# 649  2006.0   11 Jun 2006 - 15:00                    Group C
# 665  2006.0   16 Jun 2006 - 18:00                    Group C
# 682  2006.0   21 Jun 2006 - 21:00                    Group C
# 695  2006.0   25 Jun 2006 - 21:00                Round of 16
# 716  2010.0   14 Jun 2010 - 13:30                    Group E
# 731  2010.0   19 Jun 2010 - 13:30                    Group E
# 751  2010.0   24 Jun 2010 - 20:30                    Group E
# 760  2010.0   28 Jun 2010 - 16:00                Round of 16
# 764  2010.0   02 Jul 2010 - 16:00             Quarter-finals
# 768  2010.0   06 Jul 2010 - 20:30                Semi-finals
# 771  2010.0   11 Jul 2010 - 20:30                      Final
# 774  2014.0   13 Jun 2014 - 16:00                    Group B
# 789  2014.0   18 Jun 2014 - 13:00                    Group B
# 805  2014.0   23 Jun 2014 - 13:00                    Group B
# 827  2014.0   12 Jul 2014 - 17:00   Play-off for third place
# 829  2014.0   09 Jul 2014 - 17:00                Semi-finals
# 830  2014.0   05 Jul 2014 - 17:00             Quarter-finals
# 832  2014.0   29 Jun 2014 - 13:00                Round of 16
# 838  2014.0   29 Jun 2014 - 13:00                Round of 16
# 847  2014.0   05 Jul 2014 - 17:00             Quarter-finals
# 849  2014.0   09 Jul 2014 - 17:00                Semi-finals
# 850  2014.0   12 Jul 2014 - 17:00   Play-off for third place
#
#                                                Stadium  \
# 20                                            San Siro
# 41                                         Cavee Verte
# 236                               Niedersachsenstadion
# 244                                   Westfalenstadion
# 252                                   Westfalenstadion
# 258                                        Parkstadion
# 262                                        Parkstadion
# 265                                   Westfalenstadion
# 269                                     Olympiastadion
# 277                                         San Martin
# 285                                         San Martin
# 293                                         San Martin
# 295                  Estadio Ol�mpico Chateau Carreras
# 300                  Estadio Ol�mpico Chateau Carreras
# 302  El Monumental - Estadio Monumental Antonio Ves...
# 307  El Monumental - Estadio Monumental Antonio Ves...
# 422                                     Della Favorita
# 432                                          Sant Elia
# 446                                     Della Favorita
# 451                                    Giuseppe Meazza
# 472                                        RFK Stadium
# 484                                        Citrus Bowl
# 496                                        Citrus Bowl
# 504                                        Citrus Bowl
# 509                                        Cotton Bowl
# 525                                    Stade de France
# 542                                    Stade V�lodrome
# 557                            Stade Geoffroy Guichard
# 569                                    Stade Municipal
# 574                                    Stade V�lodrome
# 576                                    Stade V�lodrome
# 578                                   Parc des Princes
# 649                                     Zentralstadion
# 665                           Gottlieb-Daimler-Stadion
# 682                  FIFA World Cup Stadium, Frankfurt
# 695                                    Franken-Stadion
# 716                                Soccer City Stadium
# 731                                     Durban Stadium
# 751                                  Cape Town Stadium
# 760                                     Durban Stadium
# 764                             Port Elizabeth Stadium
# 768                                  Cape Town Stadium
# 771                                Soccer City Stadium
# 774                                   Arena Fonte Nova
# 789                                  Estadio Beira-Rio
# 805                                 Arena de Sao Paulo
# 827                                   Estadio Nacional
# 829                                 Arena de Sao Paulo
# 830                                   Arena Fonte Nova
# 832                                   Estadio Castelao
# 838                                   Estadio Castelao
# 847                                   Arena Fonte Nova
# 849                                 Arena de Sao Paulo
# 850                                   Estadio Nacional
#
#                                    City             Home Team Name  \
# 20                               Milan                 Switzerland
# 41                            Le Havre              Czechoslovakia
# 236                            Hanover                     Uruguay
# 244                           Dortmund                 Netherlands
# 252                           Dortmund                    Bulgaria
# 258                      Gelsenkirchen                 Netherlands
# 262                      Gelsenkirchen                   German DR
# 265                           Dortmund                 Netherlands
# 269                             Munich                 Netherlands
# 277                            Mendoza                 Netherlands
# 285                            Mendoza                 Netherlands
# 293                            Mendoza                    Scotland
# 295                            Cordoba                 Netherlands
# 300                            Cordoba                  Germany FR
# 302                       Buenos Aires                 Netherlands
# 307                       Buenos Aires                   Argentina
# 422                            Palermo                 Netherlands
# 432                           Cagliari                     England
# 446                            Palermo     rn">Republic of Ireland
# 451                              Milan                  Germany FR
# 472                      Washington Dc                 Netherlands
# 484                            Orlando                     Belgium
# 496                            Orlando                     Morocco
# 504                            Orlando                 Netherlands
# 509                             Dallas                 Netherlands
# 525                        Saint-Denis                 Netherlands
# 542                         Marseilles                 Netherlands
# 557                      Saint-Etienne                 Netherlands
# 569                           Toulouse                 Netherlands
# 574                         Marseilles                 Netherlands
# 576                         Marseilles                      Brazil
# 578                              Paris                 Netherlands
# 649                            Leipzig   rn">Serbia and Montenegro
# 665                          Stuttgart                 Netherlands
# 682                     Frankfurt/Main                 Netherlands
# 695                          Nuremberg                    Portugal
# 716                       Johannesburg                 Netherlands
# 731                             Durban                 Netherlands
# 751                          Cape Town                    Cameroon
# 760                             Durban                 Netherlands
# 764  Nelson Mandela Bay/Port Elizabeth                 Netherlands
# 768                          Cape Town                     Uruguay
# 771                       Johannesburg                 Netherlands
# 774                           Salvador                       Spain
# 789                       Porto Alegre                   Australia
# 805                          Sao Paulo                 Netherlands
# 827                           Brasilia                      Brazil
# 829                          Sao Paulo                 Netherlands
# 830                           Salvador                 Netherlands
# 832                          Fortaleza                 Netherlands
# 838                          Fortaleza                 Netherlands
# 847                           Salvador                 Netherlands
# 849                          Sao Paulo                 Netherlands
# 850                           Brasilia                      Brazil
#
#      Home Team Goals  Away Team Goals           Away Team Name  \
# 20               3.0              2.0              Netherlands
# 41               3.0              0.0              Netherlands
# 236              0.0              2.0              Netherlands
# 244              0.0              0.0                   Sweden
# 252              1.0              4.0              Netherlands
# 258              4.0              0.0                Argentina
# 262              0.0              2.0              Netherlands
# 265              2.0              0.0                   Brazil
# 269              1.0              2.0               Germany FR
# 277              3.0              0.0                  IR Iran
# 285              0.0              0.0                     Peru
# 293              3.0              2.0              Netherlands
# 295              5.0              1.0                  Austria
# 300              2.0              2.0              Netherlands
# 302              2.0              1.0                    Italy
# 307              3.0              1.0              Netherlands
# 422              1.0              1.0                    Egypt
# 432              0.0              0.0              Netherlands
# 446              1.0              1.0              Netherlands
# 451              2.0              1.0              Netherlands
# 472              2.0              1.0             Saudi Arabia
# 484              1.0              0.0              Netherlands
# 496              1.0              2.0              Netherlands
# 504              2.0              0.0  rn">Republic of Ireland
# 509              2.0              3.0                   Brazil
# 525              0.0              0.0                  Belgium
# 542              5.0              0.0           Korea Republic
# 557              2.0              2.0                   Mexico
# 569              2.0              1.0               Yugoslavia
# 574              2.0              1.0                Argentina
# 576              1.0              1.0              Netherlands
# 578              1.0              2.0                  Croatia
# 649              0.0              1.0              Netherlands
# 665              2.0              1.0            C�te d'Ivoire
# 682              0.0              0.0                Argentina
# 695              1.0              0.0              Netherlands
# 716              2.0              0.0                  Denmark
# 731              1.0              0.0                    Japan
# 751              1.0              2.0              Netherlands
# 760              2.0              1.0                 Slovakia
# 764              2.0              1.0                   Brazil
# 768              2.0              3.0              Netherlands
# 771              0.0              1.0                    Spain
# 774              1.0              5.0              Netherlands
# 789              2.0              3.0              Netherlands
# 805              2.0              0.0                    Chile
# 827              0.0              3.0              Netherlands
# 829              0.0              0.0                Argentina
# 830              0.0              0.0               Costa Rica
# 832              2.0              1.0                   Mexico
# 838              2.0              1.0                   Mexico
# 847              0.0              0.0               Costa Rica
# 849              0.0              0.0                Argentina
# 850              0.0              3.0              Netherlands
#
#                             Win conditions    ...     Half-time Away Goals  \
# 20                                            ...                      1.0
# 41    Czechoslovakia win after extra time     ...                      0.0
# 236                                           ...                      1.0
# 244                                           ...                      0.0
# 252                                           ...                      2.0
# 258                                           ...                      0.0
# 262                                           ...                      1.0
# 265                                           ...                      0.0
# 269                                           ...                      2.0
# 277                                           ...                      0.0
# 285                                           ...                      0.0
# 293                                           ...                      1.0
# 295                                           ...                      0.0
# 300                                           ...                      1.0
# 302                                           ...                      1.0
# 307        Argentina win after extra time     ...                      0.0
# 422                                           ...                      0.0
# 432                                           ...                      0.0
# 446                                           ...                      1.0
# 451                                           ...                      0.0
# 472                                           ...                      1.0
# 484                                           ...                      0.0
# 496                                           ...                      1.0
# 504                                           ...                      0.0
# 509                                           ...                      0.0
# 525                                           ...                      0.0
# 542                                           ...                      0.0
# 557                                           ...                      0.0
# 569                                           ...                      0.0
# 574                                           ...                      1.0
# 576       Brazil win on penalties (4 - 2)     ...                      0.0
# 578                                           ...                      2.0
# 649                                           ...                      1.0
# 665                                           ...                      1.0
# 682                                           ...                      0.0
# 695                                           ...                      0.0
# 716                                           ...                      0.0
# 731                                           ...                      0.0
# 751                                           ...                      1.0
# 760                                           ...                      0.0
# 764                                           ...                      1.0
# 768                                           ...                      1.0
# 771            Spain win after extra time     ...                      0.0
# 774                                           ...                      1.0
# 789                                           ...                      1.0
# 805                                           ...                      0.0
# 827                                           ...                      2.0
# 829    Argentina win on penalties (2 - 4)     ...                      0.0
# 830  Netherlands win on penalties (4 - 3)     ...                      0.0
# 832                                           ...                      0.0
# 838                                           ...                      0.0
# 847  Netherlands win on penalties (4 - 3)     ...                      0.0
# 849    Argentina win on penalties (2 - 4)     ...                      0.0
# 850                                           ...                      2.0
#
#                               Referee                         Assistant 1  \
# 20                  EKLIND Ivan (SWE)                 BERANEK Alois (AUT)
# 41              LECLERCQ Lucien (FRA)                      OLIVE D. (FRA)
# 236              PALOTAI Karoly (HUN)                 KAZAKOV Pavel (URS)
# 244            WINSEMANN Werner (CAN)              TSCHENSCHER Kurt (GER)
# 252               BOSKOVIC Tony (AUS)             BIWERSI Ferdinand (GER)
# 258                DAVIDSON Bob (SCO)              TSCHENSCHER Kurt (GER)
# 262              SCHEURER Ruedi (SUI)                LINEMAYR Erich (AUT)
# 265            TSCHENSCHER Kurt (GER)                  DAVIDSON Bob (SCO)
# 269                 TAYLOR John (ENG)    GONZALEZ ARCHUNDIA Alfonso (MEX)
# 277  GONZALEZ ARCHUNDIA Alfonso (MEX)                  WURTZ Robert (FRA)
# 285                PROKOP Adolf (GDR)       COEREZZA Norberto Angel (ARG)
# 293              LINEMAYR Erich (AUT)                PALOTAI Karoly (HUN)
# 295                 GORDON John (SCO)      ITHURRALDE Arturo Andres (ARG)
# 300          BARRETO RUIZ Ramon (URU)               COMESANA Miguel (ARG)
# 302              MARTINEZ Angel (ESP)                PESTARINO Luis (ARG)
# 307              GONELLA Sergio (ITA)            BARRETO RUIZ Ramon (URU)
# 422      SORIANO ALADREN Emilio (ESP)        CODESAL MENDEZ Edgardo (MEX)
# 432              PETROVIC Zoran (SRB)                HANSAL Mohamed (ALG)
# 446              VAUTROT Michel (FRA)                LORENC Richard (AUS)
# 451                LOUSTAU Juan (ARG)      JACOME GUERRERO Elias V. (ECU)
# 472            DIAZ VEGA Manuel (ESP)               IVANOV Valentin (RUS)
# 484            MARSIGLIA Renato (BRA)             ALVES Paulo Jorge (BRA)
# 496      TEJADA NORIEGA Alberto (PER)               ZARATE Venancio (PAR)
# 504             MIKKELSEN Peter (DEN)                DUNSTER Gordon (AUS)
# 509             BADILLA Rodrigo (CRC)     AL GHATTAN Yousif Abdulla (BAH)
# 525           COLLINA Pierluigi (ITA)                MAZZEI Gennaro (ITA)
# 542              WOJCIK Ryszard (POL)               POCIEGIEL Jacek (POL)
# 557          ALZEID Abdulrahman (KSA)       TRESACO GRACIA Fernando (ESP)
# 569    GARCIA ARANDA Jose Maria (ESP)                RAUSIS Laurent (SUI)
# 574        BRIZIO CARTER Arturo (MEX)                   POWELL Owen (JAM)
# 576                 BUJSAIM Ali (UAE)            GHADANFARI Hussain (KUW)
# 578    GONZALEZ CHAVEZ Epifanio (PAR)                ZAMMIT Emanuel (MLT)
# 649                 MERK Markus (GER)             SCHRAER Christian (GER)
# 665                  RUIZ Oscar (COL)               TAMAYO Fernando (ECU)
# 682       MEDINA CANTALEJO Luis (ESP)  GIRALDEZ CARRASCO Victoriano (ESP)
# 695             IVANOV Valentin (RUS)               GOLUBEV Nikolai (RUS)
# 716             St�phane LANNOY (FRA)                 DANSAULT Eric (FRA)
# 731             BALDASSI Hector (ARG)                 CASAS Ricardo (ARG)
# 751                  POZO Pablo (CHI)             BASUALTO Patricio (CHI)
# 760    Alberto UNDIANO MALLENCO (ESP)               MARTINEZ Fermin (ESP)
# 764            NISHIMURA Yuichi (JPN)                   SAGARA Toru (JPN)
# 768             Ravshan IRMATOV (UZB)                ILYASOV Rafael (UZB)
# 771                 WEBB Howard (ENG)                   Darren CANN (ENG)
# 774              Nicola RIZZOLI (ITA)               Renato FAVERANI (ITA)
# 789             HAIMOUDI Djamel (ALG)                ACHIK Redouane (MAR)
# 805              Bakary GASSAMA (GAM)            MENKOUANDE Evarist (CMR)
# 827             HAIMOUDI Djamel (ALG)                ACHIK Redouane (MAR)
# 829                C�neyt �AKIR (TUR)                DURAN Bahattin (TUR)
# 830             Ravshan IRMATOV (UZB)         RASULOV Abduxamidullo (UZB)
# 832               PROENCA Pedro (POR)               MIRANDA Bertino (POR)
# 838               PROENCA Pedro (POR)               MIRANDA Bertino (POR)
# 847             Ravshan IRMATOV (UZB)         RASULOV Abduxamidullo (UZB)
# 849                C�neyt �AKIR (TUR)                DURAN Bahattin (TUR)
# 850             HAIMOUDI Djamel (ALG)                ACHIK Redouane (MAR)
#
#                               Assistant 2     RoundID      MatchID  \
# 20              BONIVENTO Ferruccio (ITA)       204.0       1133.0
# 41                      SDEZ Victor (FRA)       206.0       1172.0
# 236                  RAINEA Nicolae (ROU)       262.0       2098.0
# 244                    THOMAS Clive (WAL)       262.0       2097.0
# 252               ESCHWEILER Walter (GER)       262.0       1990.0
# 258                   KAZAKOV Pavel (URS)       263.0       1948.0
# 262                    DELGADO Omar (COL)       263.0       2067.0
# 265                  SUPPIAH George (SIN)       263.0       1983.0
# 269              BARRETO RUIZ Ramon (URU)       605.0       2063.0
# 277                 COMESANA Miguel (ARG)       278.0       2388.0
# 285                  IVANOV Anatoly (URS)       278.0       2394.0
# 293                     SEOUDI Hedi (TUN)       278.0       2395.0
# 295                    BOUZO Farouk (SYR)       279.0       2220.0
# 300                  COELHO Arnaldo (BRA)       279.0       2348.0
# 302           OROZCO GUERRERO Cesar (PER)       279.0       2391.0
# 307                  LINEMAYR Erich (AUT)       639.0       2198.0
# 422  CARDELLINO DE SAN VICENTE Juan (URU)       322.0        151.0
# 432          CODESAL MENDEZ Edgardo (MEX)       322.0        160.0
# 446                  HANSAL Mohamed (ALG)       322.0        228.0
# 451                   MAURO Vincent (USA)       323.0        196.0
# 472                   MARTON Sandor (HUN)       337.0       3058.0
# 484              LISTKIEWICZ Michal (POL)       337.0       3069.0
# 496                 EVERSTIG Mikael (SWE)       337.0       3081.0
# 504                 BRAZZALE Eugene (AUS)       338.0       3089.0
# 509                 FANAEI Mohammad (IRN)       796.0       3098.0
# 525                  ZAMMIT Emanuel (MLT)      1014.0       8733.0
# 542                    DUPANOV Yuri (BLR)      1014.0       8749.0
# 557              GHADANFARI Hussain (KUW)      1014.0       8766.0
# 569              GRIGORESCU Nicolae (ROU)      1024.0       8778.0
# 574                SALINAS Reynaldo (HON)      1025.0       8784.0
# 576               AL MUSAWI Mohamed (OMA)      1026.0       8785.0
# 578                     FRED Lencie (VAN)      1028.0       8787.0
# 649              SALVER Jan-Hendrik (GER)  97410100.0   97410006.0
# 665                      NAVIA Jose (COL)  97410100.0   97410022.0
# 682          MEDINA HERNANDEZ Pedro (ESP)  97410100.0   97410037.0
# 695                  VOLNIN Evgueni (RUS)  97410200.0   97410052.0
# 716                     UGO Laurent (FRA)    249722.0  300061478.0
# 731                  MAIDANA Hernan (ARG)    249722.0  300111117.0
# 751               MONDRIA Francisco (CHI)    249722.0  300061473.0
# 760                      YUSTE Juan (ESP)    249717.0  300111113.0
# 764                  JEONG Hae Sang (KOR)    249718.0  300061507.0
# 768              KOCHKAROV Bakhadyr (KGZ)    249719.0  300061512.0
# 771               MULLARKEY Michael (ENG)    249721.0  300061509.0
# 774                  Andrea STEFANI (ITA)    255931.0  300186510.0
# 789               ETCHIALI Abdelhak (ALG)    255931.0  300186478.0
# 805                KABANDA Felicien (RWA)    255931.0  300186470.0
# 827               ETCHIALI Abdelhak (ALG)    255957.0  300186502.0
# 829                     ONGUN Tarik (TUR)    255955.0  300186490.0
# 830              KOCHKAROV Bakhadyr (KGZ)    255953.0  300186488.0
# 832                      TRIGO Jose (POR)    255951.0  300186508.0
# 838                      TRIGO Jose (POR)    255951.0  300186508.0
# 847              KOCHKAROV Bakhadyr (KGZ)    255953.0  300186488.0
# 849                     ONGUN Tarik (TUR)    255955.0  300186490.0
# 850               ETCHIALI Abdelhak (ALG)    255957.0  300186502.0
#
#      Home Team Initials  Away Team Initials Played in ND ND Played
# 20                  SUI                 NED           ND       NaN
# 41                  TCH                 NED           ND       NaN
# 236                 URU                 NED           ND       NaN
# 244                 NED                 SWE           ND       Yes
# 252                 BUL                 NED           ND       NaN
# 258                 NED                 ARG           ND       Yes
# 262                 GDR                 NED           ND       NaN
# 265                 NED                 BRA           ND       Yes
# 269                 NED                 FRG           ND       Yes
# 277                 NED                 IRN           ND       Yes
# 285                 NED                 PER           ND       Yes
# 293                 SCO                 NED           ND       NaN
# 295                 NED                 AUT           ND       Yes
# 300                 FRG                 NED           ND       NaN
# 302                 NED                 ITA           ND       Yes
# 307                 ARG                 NED           ND       NaN
# 422                 NED                 EGY           ND       Yes
# 432                 ENG                 NED           ND       NaN
# 446                 IRL                 NED           ND       NaN
# 451                 FRG                 NED           ND       NaN
# 472                 NED                 KSA           ND       Yes
# 484                 BEL                 NED           ND       NaN
# 496                 MAR                 NED           ND       NaN
# 504                 NED                 IRL           ND       Yes
# 509                 NED                 BRA           ND       Yes
# 525                 NED                 BEL           ND       Yes
# 542                 NED                 KOR           ND       Yes
# 557                 NED                 MEX           ND       Yes
# 569                 NED                 YUG           ND       Yes
# 574                 NED                 ARG           ND       Yes
# 576                 BRA                 NED           ND       NaN
# 578                 NED                 CRO           ND       Yes
# 649                 SCG                 NED           ND       NaN
# 665                 NED                 CIV           ND       Yes
# 682                 NED                 ARG           ND       Yes
# 695                 POR                 NED           ND       NaN
# 716                 NED                 DEN           ND       Yes
# 731                 NED                 JPN           ND       Yes
# 751                 CMR                 NED           ND       NaN
# 760                 NED                 SVK           ND       Yes
# 764                 NED                 BRA           ND       Yes
# 768                 URU                 NED           ND       NaN
# 771                 NED                 ESP           ND       Yes
# 774                 ESP                 NED           ND       NaN
# 789                 AUS                 NED           ND       NaN
# 805                 NED                 CHI           ND       Yes
# 827                 BRA                 NED           ND       NaN
# 829                 NED                 ARG           ND       Yes
# 830                 NED                 CRC           ND       Yes
# 832                 NED                 MEX           ND       Yes
# 838                 NED                 MEX           ND       Yes
# 847                 NED                 CRC           ND       Yes
# 849                 NED                 ARG           ND       Yes
# 850                 BRA                 NED           ND       NaN
#
# [54 rows x 22 columns]

# %% [markdown]
# Next, let's try and figure out how many games the USA played in the 2014 world cup.

# %%
df.loc[(df['Year']== 2014.0)& (df['Away Team Name']=='USA')|(df['Home Team Name']=='USA') ]
# Out:
#        Year              Datetime        Stage  \
# 1    1930.0  13 Jul 1930 - 15:00       Group 4
# 7    1930.0  17 Jul 1930 - 14:45       Group 4
# 62   1950.0  29 Jun 1950 - 15:00       Group 2
# 416  1990.0  10 Jun 1990 - 17:00       Group A
# 466  1994.0  18 Jun 1994 - 11:30       Group A
# 478  1994.0  22 Jun 1994 - 19:30       Group A
# 488  1994.0  26 Jun 1994 - 16:00       Group A
# 545  1998.0  21 Jun 1998 - 21:00       Group F
# 559  1998.0  25 Jun 1998 - 21:00       Group F
# 595  2002.0  05 Jun 2002 - 18:00       Group D
# 653  2006.0  12 Jun 2006 - 18:00       Group E
# 745  2010.0  23 Jun 2010 - 16:00       Group C
# 757  2010.0  26 Jun 2010 - 20:30   Round of 16
# 785  2014.0  16 Jun 2014 - 19:00       Group G
# 803  2014.0  22 Jun 2014 - 18:00       Group G
# 816  2014.0  26 Jun 2014 - 13:00       Group G
# 835  2014.0  01 Jul 2014 - 17:00   Round of 16
# 843  2014.0  01 Jul 2014 - 17:00   Round of 16
#
#                                    Stadium               City Home Team Name  \
# 1                           Parque Central        Montevideo             USA
# 7                           Parque Central        Montevideo             USA
# 62                           Independencia    Belo Horizonte             USA
# 416                               Comunale          Florence             USA
# 466                     Pontiac Silverdome           Detroit             USA
# 478                              Rose Bowl       Los Angeles             USA
# 488                              Rose Bowl       Los Angeles             USA
# 545                       Stade de Gerland              Lyon             USA
# 559                           La Beaujoire            Nantes             USA
# 595                Suwon World Cup Stadium             Suwon             USA
# 653  FIFA World Cup Stadium, Gelsenkirchen     Gelsenkirchen             USA
# 745                Loftus Versfeld Stadium  Tshwane/Pretoria             USA
# 757           Royal Bafokeng Sports Palace           Phokeng             USA
# 785                      Estadio das Dunas             Natal           Ghana
# 803                         Arena Amazonia            Manaus             USA
# 816                       Arena Pernambuco            Recife             USA
# 835                       Arena Fonte Nova          Salvador         Belgium
# 843                       Arena Fonte Nova          Salvador         Belgium
#
#      Home Team Goals  Away Team Goals  Away Team Name  \
# 1                3.0              0.0         Belgium
# 7                3.0              0.0        Paraguay
# 62               1.0              0.0         England
# 416              1.0              5.0  Czechoslovakia
# 466              1.0              1.0     Switzerland
# 478              2.0              1.0        Colombia
# 488              0.0              1.0         Romania
# 545              1.0              2.0            Iran
# 559              0.0              1.0      Yugoslavia
# 595              3.0              2.0        Portugal
# 653              0.0              3.0  Czech Republic
# 745              1.0              0.0         Algeria
# 757              1.0              2.0           Ghana
# 785              1.0              2.0             USA
# 803              2.0              2.0        Portugal
# 816              0.0              1.0         Germany
# 835              2.0              1.0             USA
# 843              2.0              1.0             USA
#
#                     Win conditions    ...     Half-time Away Goals  \
# 1                                     ...                      0.0
# 7                                     ...                      0.0
# 62                                    ...                      0.0
# 416                                   ...                      2.0
# 466                                   ...                      1.0
# 478                                   ...                      0.0
# 488                                   ...                      1.0
# 545                                   ...                      1.0
# 559                                   ...                      1.0
# 595                                   ...                      1.0
# 653                                   ...                      2.0
# 745                                   ...                      0.0
# 757    Ghana win after extra time     ...                      0.0
# 785                                   ...                      1.0
# 803                                   ...                      1.0
# 816                                   ...                      0.0
# 835  Belgium win after extra time     ...                      0.0
# 843  Belgium win after extra time     ...                      0.0
#
#                             Referee                  Assistant 1  \
# 1                 MACIAS Jose (ARG)     MATEUCCI Francisco (URU)
# 7                 MACIAS Jose (ARG)      APHESTEGUY Martin (URU)
# 62           DATTILO Generoso (ITA)    DE LA SALLE Charles (FRA)
# 416       ROETHLISBERGER Kurt (SUI)  VAN LANGENHOVE Marcel (BEL)
# 466  LAMOLINA Francisco Oscar (ARG)          TAIBI Ernesto (ARG)
# 478              BALDAS Fabio (ITA)      RAMICONE Domenico (ITA)
# 488        VAN DER ENDE Mario (NED)            DOLSTRA Jan (NED)
# 545                 MEIER Urs (SUI)         RAUSIS Laurent (SUI)
# 559         EL GHANDOUR Gamal (EGY)           SALIE Achmat (RSA)
# 595              MORENO Byron (ECU)           FIERRO Bomer (ECU)
# 653           AMARILLA Carlos (PAR)          ANDINO Amelio (PAR)
# 745        DE BLEECKERE Frank (BEL)          HERMANS Peter (BEL)
# 757             KASSAI Viktor (HUN)             EROS Gabor (HUN)
# 785            ERIKSSON Jonas (SWE)      KLASENIUS Mathias (SWE)
# 803             PITANA Nestor (ARG)         MAIDANA Hernan (ARG)
# 816           Ravshan IRMATOV (UZB)  RASULOV Abduxamidullo (UZB)
# 835           HAIMOUDI Djamel (ALG)         ACHIK Redouane (MAR)
# 843           HAIMOUDI Djamel (ALG)         ACHIK Redouane (MAR)
#
#                         Assistant 2     RoundID      MatchID  \
# 1             WARNKEN Alberto (CHI)       201.0       1090.0
# 7               TEJADA Anibal (URU)       201.0       1097.0
# 62           GALEATI Giovanni (ITA)       208.0       1202.0
# 416          SCHMIDHUBER Aron (GER)       322.0        355.0
# 466           ZARATE Venancio (PAR)       337.0       3051.0
# 478  RHARIB El Jilali Mohamed (MAR)       337.0       3063.0
# 488            DUNSTER Gordon (AUS)       337.0       3073.0
# 545        GRIGORESCU Nicolae (ROU)      1014.0       8754.0
# 559               WARREN Mark (ENG)      1014.0       8768.0
# 595            HASSOUNEH Awni (JOR)  43950100.0   43950016.0
# 653             BERNAL Manuel (PAR)  97410100.0   97410010.0
# 745            VROMANS Walter (BEL)    249722.0  300061461.0
# 757               VAMOS Tibor (HUN)    249717.0  300061503.0
# 785           WARNMARK Daniel (SWE)    255931.0  300186512.0
# 803        BELATTI Juan Pablo (ARG)    255931.0  300186483.0
# 816        KOCHKAROV Bakhadyr (KGZ)    255931.0  300186469.0
# 835         ETCHIALI Abdelhak (ALG)    255951.0  300186497.0
# 843         ETCHIALI Abdelhak (ALG)    255951.0  300186497.0
#
#      Home Team Initials  Away Team Initials Played in ND ND Played
# 1                   USA                 BEL           ND       NaN
# 7                   USA                 PAR           ND       NaN
# 62                  USA                 ENG           ND       NaN
# 416                 USA                 TCH           ND       NaN
# 466                 USA                 SUI           ND       NaN
# 478                 USA                 COL           ND       NaN
# 488                 USA                 ROU           ND       NaN
# 545                 USA                 IRN           ND       NaN
# 559                 USA                 YUG           ND       NaN
# 595                 USA                 POR           ND       NaN
# 653                 USA                 CZE           ND       NaN
# 745                 USA                 ALG           ND       NaN
# 757                 USA                 GHA           ND       NaN
# 785                 GHA                 USA           ND       NaN
# 803                 USA                 POR           ND       NaN
# 816                 USA                 GER           ND       NaN
# 835                 BEL                 USA           ND       NaN
# 843                 BEL                 USA           ND       NaN
#
# [18 rows x 22 columns]

# %% [markdown]
# Now, let's try to find out how many countries participated in the 1986 world cup.

# %% [markdown]
# Hint 1: as a first step, create a new data set that only contain games in that year.
#
# Hint 2: You can use `.unique()` to make sure you don't end up with duplicate country names.

# %%
Eightysix = df.loc[df['Year'] == 1986.0]

# %%
countries = []
for country in Eightysix['Away Team Name']:
    if country in countries:
        continue
    else: 
        countries.append(country)
for country in Eightysix['Home Team Name']:
    if country in countries:
        continue
    else: 
        countries.append(country)
print(set(countries),len(countries))
# Out:
# {'Belgium', 'England', 'Canada', 'Paraguay', 'Mexico', 'Portugal', 'Poland', 'Korea Republic', 'Argentina', 'Hungary', 'France', 'Spain', 'Soviet Union', 'Iraq', 'Germany FR', 'Brazil', 'Uruguay', 'Northern Ireland', 'Italy', 'Morocco', 'Denmark', 'Algeria', 'Scotland', 'Bulgaria'} 24

# %% [markdown]
# In the world cup history, how matches had more than 5 goals in total?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 22 columns):
# Year                    852 non-null float64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null float64
# Away Team Goals         852 non-null float64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null float64
# Half-time Away Goals    852 non-null float64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null float64
# MatchID                 852 non-null float64
# Home Team Initials      852 non-null object
# Away Team Initials      852 non-null object
# Played in ND            4572 non-null object
# ND Played               32 non-null object
# dtypes: float64(8), object(14)
# memory usage: 785.9+ KB

# %%
df["goals"]= (df["Home Team Goals"] + df["Away Team Goals"])
df.loc[df['goals']>5]
# Out:
#        Year               Datetime                  Stage  \
# 10   1930.0   19 Jul 1930 - 15:00                 Group 1
# 15   1930.0   26 Jul 1930 - 14:45             Semi-finals
# 16   1930.0   27 Jul 1930 - 14:45             Semi-finals
# 17   1930.0   30 Jul 1930 - 14:15                   Final
# 19   1934.0   27 May 1934 - 16:30       Preliminary round
# 22   1934.0   27 May 1934 - 16:30       Preliminary round
# 24   1934.0   27 May 1934 - 16:30       Preliminary round
# 36   1938.0   05 Jun 1938 - 17:00             First round
# 38   1938.0   05 Jun 1938 - 17:00             First round
# 40   1938.0   05 Jun 1938 - 17:30             First round
# 43   1938.0   09 Jun 1938 - 18:00             First round
# 46   1938.0   12 Jun 1938 - 17:00          Quarter-finals
# 49   1938.0   16 Jun 1938 - 18:00             Semi-finals
# 51   1938.0   19 Jun 1938 - 17:00   Match for third place
# 52   1938.0   19 Jun 1938 - 17:00                   Final
# 66   1950.0   02 Jul 1950 - 15:00                 Group 4
# 68   1950.0   02 Jul 1950 - 15:00                 Group 2
# 70   1950.0   09 Jul 1950 - 15:00                 Group 6
# 71   1950.0   13 Jul 1950 - 15:00                 Group 6
# 80   1954.0   17 Jun 1954 - 18:00                 Group 2
# 81   1954.0   17 Jun 1954 - 18:10                 Group 4
# 83   1954.0   19 Jun 1954 - 16:50                 Group 3
# 87   1954.0   20 Jun 1954 - 16:50                 Group 2
# 88   1954.0   20 Jun 1954 - 17:00                 Group 2
# 91   1954.0   23 Jun 1954 - 18:00                 Group 2
# 93   1954.0   26 Jun 1954 - 17:00          Quarter-finals
# 94   1954.0   26 Jun 1954 - 17:00          Quarter-finals
# 96   1954.0   27 Jun 1954 - 17:00          Quarter-finals
# 97   1954.0   30 Jun 1954 - 18:00             Semi-finals
# 98   1954.0   30 Jun 1954 - 18:00             Semi-finals
# ..      ...                    ...                    ...
# 243  1974.0   18 Jun 1974 - 19:30                 Group 2
# 246  1974.0   19 Jun 1974 - 19:30                 Group 4
# 263  1974.0   30 Jun 1974 - 19:30                 Group B
# 280  1978.0   06 Jun 1978 - 16:45                 Group 2
# 295  1978.0   14 Jun 1978 - 13:45                 Group A
# 305  1978.0   21 Jun 1978 - 19:15                 Group B
# 312  1982.0   15 Jun 1982 - 21:00                 Group 3
# 313  1982.0   15 Jun 1982 - 21:00                 Group 6
# 332  1982.0   22 Jun 1982 - 17:15                 Group 1
# 357  1982.0   08 Jul 1982 - 21:00             Semi-finals
# 363  1986.0   02 Jun 1986 - 12:00                 Group C
# 382  1986.0   08 Jun 1986 - 16:00                 Group E
# 396  1986.0   15 Jun 1986 - 16:00             Round of 16
# 403  1986.0   18 Jun 1986 - 16:00             Round of 16
# 410  1986.0   28 Jun 1986 - 12:00   Match for third place
# 416  1990.0   10 Jun 1990 - 17:00                 Group A
# 429  1990.0   15 Jun 1990 - 21:00                 Group D
# 495  1994.0   28 Jun 1994 - 16:00                 Group B
# 554  1998.0   24 Jun 1998 - 21:00                 Group D
# 583  2002.0   01 Jun 2002 - 20:30                 Group E
# 613  2002.0  11 June 2002 - 15:30                 Group A
# 620  2002.0   13 Jun 2002 - 15:30                 Group C
# 644  2006.0   09 Jun 2006 - 18:00                 Group A
# 664  2006.0   16 Jun 2006 - 15:00                 Group C
# 737  2010.0   21 Jun 2010 - 13:30                 Group G
# 774  2014.0   13 Jun 2014 - 16:00                 Group B
# 796  2014.0   20 Jun 2014 - 16:00                 Group E
# 802  2014.0   22 Jun 2014 - 16:00                 Group H
# 826  2014.0   08 Jul 2014 - 17:00             Semi-finals
# 848  2014.0   08 Jul 2014 - 17:00             Semi-finals
#
#                                          Stadium             City  \
# 10                            Estadio Centenario      Montevideo
# 15                            Estadio Centenario      Montevideo
# 16                            Estadio Centenario      Montevideo
# 17                            Estadio Centenario      Montevideo
# 19                             Giorgio Ascarelli          Naples
# 22                                Giovanni Berta        Florence
# 24                                 Nazionale PNF            Rome
# 36                          Velodrome Municipale           Reims
# 38                               Stade Municipal        Toulouse
# 40                            Stade de la Meinau      Strasbourg
# 43                              Parc des Princes           Paris
# 46                                   Fort Carree         Antibes
# 49                              Parc des Princes           Paris
# 51                         Stade du Parc Lescure        Bordeaux
# 52                               Stade Olympique        Colombes
# 66                                 Independencia  Belo Horizonte
# 68                                Ilha do Retiro          Recife
# 70     Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 71     Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 80                                      Hardturm          Zurich
# 81                                     St. Jakob           Basel
# 83                                     St. Jakob           Basel
# 87                                     St. Jakob           Basel
# 88                                    Charmilles          Geneva
# 91                                      Hardturm          Zurich
# 93                                     St. Jakob           Basel
# 94                                   La Pontaise        Lausanne
# 96                              Wankdorf Stadium           Berne
# 97                                     St. Jakob           Basel
# 98                                   La Pontaise        Lausanne
# ..                                           ...              ...
# 243                                  Parkstadion   Gelsenkirchen
# 246                               Olympiastadion          Munich
# 263                                 Rheinstadion      D�Sseldorf
# 280            Estadio Ol�mpico Chateau Carreras         Cordoba
# 295            Estadio Ol�mpico Chateau Carreras         Cordoba
# 305  Arroyito - Estadio Dr. Lisandro de la Torre         Rosario
# 312                                Nuevo Estadio           Elche
# 313                                  La Rosaleda          Malaga
# 332                                       Riazor       La Coru�A
# 357                        Ramon Sanchez Pizjuan         Seville
# 363                             Estadio Irapuato        Irapuato
# 382                                         Neza  Nezahualcoyotl
# 396                      Nou Camp - Estadio Le�n            Leon
# 403                          Estadio Corregidora       Queretaro
# 410                                   Cuauhtemoc          Puebla
# 416                                     Comunale        Florence
# 429                              Giuseppe Meazza           Milan
# 495                             Stanford Stadium   San Francisco
# 554                         Stade Felix Bollaert            Lens
# 583                                 Sapporo Dome         Sapporo
# 613                      Suwon World Cup Stadium           Suwon
# 620                      Suwon World Cup Stadium           Suwon
# 644               FIFA World Cup Stadium, Munich          Munich
# 664        FIFA World Cup Stadium, Gelsenkirchen   Gelsenkirchen
# 737                            Cape Town Stadium       Cape Town
# 774                             Arena Fonte Nova        Salvador
# 796                             Arena Fonte Nova        Salvador
# 802                            Estadio Beira-Rio    Porto Alegre
# 826                             Estadio Mineirao  Belo Horizonte
# 848                             Estadio Mineirao  Belo Horizonte
#
#      Home Team Name  Home Team Goals  Away Team Goals  \
# 10        Argentina              6.0              3.0
# 15        Argentina              6.0              1.0
# 16          Uruguay              6.0              1.0
# 17          Uruguay              4.0              2.0
# 19          Hungary              4.0              2.0
# 22          Germany              5.0              2.0
# 24            Italy              7.0              1.0
# 36          Hungary              6.0              0.0
# 38             Cuba              3.0              3.0
# 40           Brazil              6.0              5.0
# 43      Switzerland              4.0              2.0
# 46           Sweden              8.0              0.0
# 49          Hungary              5.0              1.0
# 51           Brazil              4.0              2.0
# 52            Italy              4.0              2.0
# 66          Uruguay              8.0              0.0
# 68            Chile              5.0              2.0
# 70           Brazil              7.0              1.0
# 71           Brazil              6.0              1.0
# 80          Hungary              9.0              0.0
# 81          England              4.0              4.0
# 83          Uruguay              7.0              0.0
# 87          Hungary              8.0              3.0
# 88           Turkey              7.0              0.0
# 91       Germany FR              7.0              2.0
# 93          Uruguay              4.0              2.0
# 94          Austria              7.0              5.0
# 96          Hungary              4.0              2.0
# 97       Germany FR              6.0              1.0
# 98          Hungary              4.0              2.0
# ..              ...              ...              ...
# 243      Yugoslavia              9.0              0.0
# 246           Haiti              0.0              7.0
# 263      Germany FR              4.0              2.0
# 280      Germany FR              6.0              0.0
# 295     Netherlands              5.0              1.0
# 305       Argentina              6.0              0.0
# 312         Hungary             10.0              1.0
# 313        Scotland              5.0              2.0
# 332          Poland              5.0              1.0
# 357      Germany FR              3.0              3.0
# 363    Soviet Union              6.0              0.0
# 382         Denmark              6.0              1.0
# 396    Soviet Union              3.0              4.0
# 403         Denmark              1.0              5.0
# 410          France              4.0              2.0
# 416             USA              1.0              5.0
# 429      Germany FR              5.0              1.0
# 495          Russia              6.0              1.0
# 554           Spain              6.0              1.0
# 583         Germany              8.0              0.0
# 613         Senegal              3.0              3.0
# 620      Costa Rica              2.0              5.0
# 644         Germany              4.0              2.0
# 664       Argentina              6.0              0.0
# 737        Portugal              7.0              0.0
# 774           Spain              1.0              5.0
# 796     Switzerland              2.0              5.0
# 802  Korea Republic              2.0              4.0
# 826          Brazil              1.0              7.0
# 848          Brazil              1.0              7.0
#
#                 Away Team Name                 Win conditions  ...   \
# 10                      Mexico                                 ...
# 15                         USA                                 ...
# 16                  Yugoslavia                                 ...
# 17                   Argentina                                 ...
# 19                       Egypt                                 ...
# 22                     Belgium                                 ...
# 24                         USA                                 ...
# 36           Dutch East Indies                                 ...
# 38                     Romania                                 ...
# 40                      Poland   Brazil win after extra time   ...
# 43                     Germany                                 ...
# 46                        Cuba                                 ...
# 49                      Sweden                                 ...
# 51                      Sweden                                 ...
# 52                     Hungary                                 ...
# 66                     Bolivia                                 ...
# 68                         USA                                 ...
# 70                      Sweden                                 ...
# 71                       Spain                                 ...
# 80              Korea Republic                                 ...
# 81                     Belgium                                 ...
# 83                    Scotland                                 ...
# 87                  Germany FR                                 ...
# 88              Korea Republic                                 ...
# 91                      Turkey                                 ...
# 93                     England                                 ...
# 94                 Switzerland                                 ...
# 96                      Brazil                                 ...
# 97                     Austria                                 ...
# 98                     Uruguay  Hungary win after extra time   ...
# ..                         ...                            ...  ...
# 243                      Zaire                                 ...
# 246                     Poland                                 ...
# 263                     Sweden                                 ...
# 280                     Mexico                                 ...
# 295                    Austria                                 ...
# 305                       Peru                                 ...
# 312                El Salvador                                 ...
# 313                New Zealand                                 ...
# 332                       Peru                                 ...
# 357                     France      win on penalties (5 - 4)   ...
# 363                    Hungary                                 ...
# 382                    Uruguay                                 ...
# 396                    Belgium  Belgium win after extra time   ...
# 403                      Spain                                 ...
# 410                    Belgium   France win after extra time   ...
# 416             Czechoslovakia                                 ...
# 429   rn">United Arab Emirates                                 ...
# 495                   Cameroon                                 ...
# 554                   Bulgaria                                 ...
# 583               Saudi Arabia                                 ...
# 613                    Uruguay                                 ...
# 620                     Brazil                                 ...
# 644                 Costa Rica                                 ...
# 664  rn">Serbia and Montenegro                                 ...
# 737                  Korea DPR                                 ...
# 774                Netherlands                                 ...
# 796                     France                                 ...
# 802                    Algeria                                 ...
# 826                    Germany                                 ...
# 848                    Germany                                 ...
#
#                            Referee                       Assistant 1  \
# 10            SAUCEDO Ulises (BOL)            ALONSO Gualberto (URU)
# 15             LANGENUS Jean (BEL)              VALLEJO Gaspar (MEX)
# 16             REGO Gilberto (BRA)              SAUCEDO Ulises (BOL)
# 17             LANGENUS Jean (BEL)              SAUCEDO Ulises (BOL)
# 19        BARLASSINA Rinaldo (ITA)            DATTILO Generoso (ITA)
# 22          MATTEA Francesco (ITA)        MELANDRI Ermenegildo (ITA)
# 24               MERCET Rene (SUI)              ESCARTIN Pedro (ESP)
# 36              CONRIE Roger (FRA)         DE LA SALLE Charles (FRA)
# 38           SCARPI Giuseppe (ITA)          VALPREDE Ferdinand (FRA)
# 40               EKLIND Ivan (SWE)              POISSANT Louis (FRA)
# 43               EKLIND Ivan (SWE)                 BAERT Louis (BEL)
# 46              KRIST Gustav (TCH)            WEINGARTNER Karl (AUT)
# 49           LECLERCQ Lucien (FRA)        VAN MOORSEL Johannes (NED)
# 51             LANGENUS Jean (BEL)                    OLIVE D. (FRA)
# 52        CAPDEVILLE Georges (FRA)              WUETHRICH Hans (SUI)
# 66             READER George (ENG)                 VIANA Mario (BRA)
# 68            GARDELLI Mario (BRA)           HEYEN Mario Ruben (PAR)
# 70              ELLIS Arthur (ENG)            GARCIA Prudencio (USA)
# 71            LEAFE Reginald (ENG)             MITCHELL George (SCO)
# 80          VINCENTI Raymond (FRA)           VON GUNTER Albert (SUI)
# 81            SCHMETZER Emil (FRG)           BUCHMUELLER Fritz (SUI)
# 83        ORLANDINI Vincenzo (ITA)               WYSSLING Paul (SUI)
# 87              LING William (ENG)             SCHICKER Werner (SUI)
# 88            MARINO Esteban (URU)          ORLANDINI Vincenzo (ITA)
# 91          VINCENTI Raymond (FRA)           FAULTLESS Charlie (SCO)
# 93              STEINER Carl (AUT)             STEFANOVIC Vasa (YUG)
# 94         FAULTLESS Charlie (SCO)               ASENSI Manuel (ESP)
# 96              ELLIS Arthur (ENG)                LING William (ENG)
# 97        ORLANDINI Vincenzo (ITA)                ELLIS Arthur (ENG)
# 98        GRIFFITHS Benjamin (WAL)           FAULTLESS Charlie (SCO)
# ..                             ...                               ...
# 243             DELGADO Omar (COL)           LLOBREGAT Vicente (VEN)
# 246           SUPPIAH George (SIN)           BIWERSI Ferdinand (GER)
# 263            KAZAKOV Pavel (URS)              RAINEA Nicolae (ROU)
# 280             BOUZO Farouk (SYR)             GARRIDO Antonio (POR)
# 295              GORDON John (SCO)    ITHURRALDE Arturo Andres (ARG)
# 305             WURTZ Robert (FRA)           BIWERSI Ferdinand (GER)
# 312           AL DOY Ebrahim (BHR)              CORVER Charles (NED)
# 313              SOCHA David (USA)        CHAN Thomson Tam Sun (HKG)
# 332      RUBIO VAZQUEZ Mario (MEX)      SORIANO ALADREN Emilio (ESP)
# 357           CORVER Charles (NED)                GALLER Bruno (SUI)
# 363            AGNOLIN Luigi (ITA)             COURTNEY George (ENG)
# 382  MARQUEZ RAMIREZ Antonio (MEX)                  KEIZER Jan (NED)
# 396         FREDRIKSSON Erik (SWE)  SANCHEZ ARMINIO Victoriano (ESP)
# 403               KEIZER Jan (NED)               BENNACEUR Ali (TUN)
# 410          COURTNEY George (ENG)           SILVA ARCE Hernan (CHI)
# 416      ROETHLISBERGER Kurt (SUI)       VAN LANGENHOVE Marcel (BEL)
# 429            SPIRIN Alexey (RUS)               TAKADA Shizuo (JPN)
# 495          AL SHARIF Jamal (SYR)              DUNSTER Gordon (AUS)
# 554       VAN DER ENDE Mario (NED)          GRIGORESCU Nicolae (ROU)
# 583            AQUINO Ubaldo (PAR)           GIACOMUZZI Miguel (PAR)
# 613             WEGEREEF Jan (NED)                   POOL Jaap (NED)
# 620        EL GHANDOUR Gamal (EGY)                 FARAG Wagih (EGY)
# 644         ELIZONDO Horacio (ARG)                GARCIA Dario (ARG)
# 664          ROSETTI Roberto (ITA)           COPELLI Cristiano (ITA)
# 737               POZO Pablo (CHI)           BASUALTO Patricio (CHI)
# 774           Nicola RIZZOLI (ITA)             Renato FAVERANI (ITA)
# 796            Bj�rn KUIPERS (NED)           Sander VAN ROEKEL (NED)
# 802            ROLDAN Wilmar (COL)                DIAZ Eduardo (COL)
# 826          RODRIGUEZ Marco (MEX)           TORRENTERA Marvin (MEX)
# 848          RODRIGUEZ Marco (MEX)           TORRENTERA Marvin (MEX)
#
#                           Assistant 2     RoundID      MatchID  \
# 10         RADULESCU Constantin (ROU)       201.0       1086.0
# 15              WARNKEN Alberto (CHI)       202.0       1088.0
# 16                BALWAY Thomas (FRA)       202.0       1101.0
# 17              CRISTOPHE Henry (BEL)       405.0       1087.0
# 19                 SASSI Otello (ITA)       204.0       1119.0
# 22                BAERT Jacques (FRA)       204.0       1108.0
# 24              ZENISEK Bohumil (TCH)       204.0       1135.0
# 36             WEINGARTNER Karl (AUT)       206.0       1173.0
# 38                  MERKCX Jean (FRA)       206.0       1156.0
# 40          KISSENBERGER Ernest (FRA)       206.0       1150.0
# 43         VAN MOORSEL Johannes (NED)       206.0       1166.0
# 46                  SDEZ Victor (FRA)       429.0       1158.0
# 49              SCARPI Giuseppe (ITA)      3489.0       1176.0
# 51           VALPREDE Ferdinand (FRA)      3488.0       1151.0
# 52                 KRIST Gustav (TCH)      3487.0       1174.0
# 66                  LEMESIC Leo (YUG)       208.0       1185.0
# 68              ALVAREZ Alfredo (BOL)       208.0       1194.0
# 70          DE LA SALLE Charles (FRA)       209.0       1189.0
# 71         DA COSTA VIEIRA Jose (POR)       209.0       1186.0
# 80                 STEINER Carl (AUT)       211.0       1294.0
# 81                 RUFFLI Willy (SUI)       211.0       1240.0
# 83                 GUIDI Denilo (SUI)       211.0       1313.0
# 87           GRIFFITHS Benjamin (WAL)       211.0       1277.0
# 88           SCHONHOLZER Ernest (SUI)       211.0       1304.0
# 91            DOERFLINGER Ernst (SUI)       211.0       1284.0
# 93           ORLANDINI Vincenzo (ITA)       212.0       1264.0
# 94               SCHMETZER Emil (FRG)       212.0       1237.0
# 96                WYSSLING Paul (SUI)       212.0       1248.0
# 97            BUCHMUELLER Fritz (SUI)       462.0       1233.0
# 98             VINCENTI Raymond (FRA)       462.0       1295.0
# ..                                ...         ...          ...
# 243          BARRETO RUIZ Ramon (URU)       262.0       2186.0
# 246           ESCHWEILER Walter (GER)       262.0       2085.0
# 263        SANCHEZ IBANEZ Pablo (ESP)       263.0       2065.0
# 280                RION Francis (BEL)       278.0       2350.0
# 295                BOUZO Farouk (SYR)       279.0       2220.0
# 305              GONELLA Sergio (ITA)       279.0       2201.0
# 312       LUND-SORENSEN Henning (DEN)       293.0        896.0
# 313      EL GHOUL Yusef Mohamed (LBY)       293.0       1051.0
# 332  SANCHEZ ARMINIO Victoriano (ESP)       293.0       1055.0
# 357            VALENTINE Robert (SCO)       295.0        914.0
# 363             BRUMMEIER Horst (AUT)       308.0        610.0
# 382        ARPPI FILHO Romualdo (BRA)       308.0        522.0
# 396                 SOCHA David (USA)       309.0        432.0
# 403              DOTCHEV Bogdan (BUL)       309.0        511.0
# 410             AL SHARIF Jamal (SYR)      3468.0        422.0
# 416            SCHMIDHUBER Aron (GER)       322.0        355.0
# 429          PAIRETTO Pierluigi (ITA)       322.0        198.0
# 495                 DOLSTRA Jan (NED)       337.0       3079.0
# 554               ROSSI Claudio (ARG)      1014.0       8761.0
# 583           RAGOONATH Michael (TRI)  43950100.0   43950004.0
# 613              SZEKELY Ferenc (HUN)  43950100.0   43950034.0
# 620               BEREUTER Egon (AUT)  43950100.0   43950041.0
# 644               OTERO Rodolfo (ARG)  97410100.0   97410001.0
# 664         STAGNOLI Alessandro (ITA)  97410100.0   97410021.0
# 737           MONDRIA Francisco (CHI)    249722.0  300061487.0
# 774              Andrea STEFANI (ITA)    255931.0  300186510.0
# 796              Erwin ZEINSTRA (NED)    255931.0  300186514.0
# 802           LESCANO Christian (ECU)    255931.0  300186495.0
# 826             QUINTERO Marcos (MEX)    255955.0  300186474.0
# 848             QUINTERO Marcos (MEX)    255955.0  300186474.0
#
#     Home Team Initials  Away Team Initials  Played in ND ND Played goals
# 10                 ARG                 MEX            ND       NaN   9.0
# 15                 ARG                 USA            ND       NaN   7.0
# 16                 URU                 YUG            ND       NaN   7.0
# 17                 URU                 ARG            ND       NaN   6.0
# 19                 HUN                 EGY            ND       NaN   6.0
# 22                 GER                 BEL            ND       NaN   7.0
# 24                 ITA                 USA            ND       NaN   8.0
# 36                 HUN                 INH            ND       NaN   6.0
# 38                 CUB                 ROU            ND       NaN   6.0
# 40                 BRA                 POL            ND       NaN  11.0
# 43                 SUI                 GER            ND       NaN   6.0
# 46                 SWE                 CUB            ND       NaN   8.0
# 49                 HUN                 SWE            ND       NaN   6.0
# 51                 BRA                 SWE            ND       NaN   6.0
# 52                 ITA                 HUN            ND       NaN   6.0
# 66                 URU                 BOL            ND       NaN   8.0
# 68                 CHI                 USA            ND       NaN   7.0
# 70                 BRA                 SWE            ND       NaN   8.0
# 71                 BRA                 ESP            ND       NaN   7.0
# 80                 HUN                 KOR            ND       NaN   9.0
# 81                 ENG                 BEL            ND       NaN   8.0
# 83                 URU                 SCO            ND       NaN   7.0
# 87                 HUN                 FRG            ND       NaN  11.0
# 88                 TUR                 KOR            ND       NaN   7.0
# 91                 FRG                 TUR            ND       NaN   9.0
# 93                 URU                 ENG            ND       NaN   6.0
# 94                 AUT                 SUI            ND       NaN  12.0
# 96                 HUN                 BRA            ND       NaN   6.0
# 97                 FRG                 AUT            ND       NaN   7.0
# 98                 HUN                 URU            ND       NaN   6.0
# ..                 ...                 ...           ...       ...   ...
# 243                YUG                 ZAI            ND       NaN   9.0
# 246                HAI                 POL            ND       NaN   7.0
# 263                FRG                 SWE            ND       NaN   6.0
# 280                FRG                 MEX            ND       NaN   6.0
# 295                NED                 AUT            ND       Yes   6.0
# 305                ARG                 PER            ND       NaN   6.0
# 312                HUN                 SLV            ND       NaN  11.0
# 313                SCO                 NZL            ND       NaN   7.0
# 332                POL                 PER            ND       NaN   6.0
# 357                FRG                 FRA            ND       NaN   6.0
# 363                URS                 HUN            ND       NaN   6.0
# 382                DEN                 URU            ND       NaN   7.0
# 396                URS                 BEL            ND       NaN   7.0
# 403                DEN                 ESP            ND       NaN   6.0
# 410                FRA                 BEL            ND       NaN   6.0
# 416                USA                 TCH            ND       NaN   6.0
# 429                FRG                 UAE            ND       NaN   6.0
# 495                RUS                 CMR            ND       NaN   7.0
# 554                ESP                 BUL            ND       NaN   7.0
# 583                GER                 KSA            ND       NaN   8.0
# 613                SEN                 URU            ND       NaN   6.0
# 620                CRC                 BRA            ND       NaN   7.0
# 644                GER                 CRC            ND       NaN   6.0
# 664                ARG                 SCG            ND       NaN   6.0
# 737                POR                 PRK            ND       NaN   7.0
# 774                ESP                 NED            ND       NaN   6.0
# 796                SUI                 FRA            ND       NaN   7.0
# 802                KOR                 ALG            ND       NaN   6.0
# 826                BRA                 GER            ND       NaN   8.0
# 848                BRA                 GER            ND       NaN   8.0
#
# [74 rows x 23 columns]

# %% [markdown]
# ## Changing values and creating new columns

# %% [markdown]
# With the information you currently have in your `df`, create a new column "Half-time Goals".

# %%
df["Half-time Goals"]= (df["Half-time Home Goals"] + df["Half-time Away Goals"])
df['Half-time Goals']
# Out:
# 0       3.0
# 1       2.0
# 2       2.0
# 3       1.0
# 4       0.0
# 5       1.0
# 6       0.0
# 7       2.0
# 8       0.0
# 9       0.0
# 10      4.0
# 11      1.0
# 12      1.0
# 13      4.0
# 14      3.0
# 15      1.0
# 16      4.0
# 17      3.0
# 18      0.0
# 19      4.0
# 20      3.0
# 21      2.0
# 22      3.0
# 23      3.0
# 24      3.0
# 25      1.0
# 26      2.0
# 27      0.0
# 28      0.0
# 29      1.0
#        ...
# 4542    NaN
# 4543    NaN
# 4544    NaN
# 4545    NaN
# 4546    NaN
# 4547    NaN
# 4548    NaN
# 4549    NaN
# 4550    NaN
# 4551    NaN
# 4552    NaN
# 4553    NaN
# 4554    NaN
# 4555    NaN
# 4556    NaN
# 4557    NaN
# 4558    NaN
# 4559    NaN
# 4560    NaN
# 4561    NaN
# 4562    NaN
# 4563    NaN
# 4564    NaN
# 4565    NaN
# 4566    NaN
# 4567    NaN
# 4568    NaN
# 4569    NaN
# 4570    NaN
# 4571    NaN
# Name: Half-time Goals, Length: 4572, dtype: float64

# %% [markdown]
# Run the code below. You'll notice that for Korea, there are records for both North-Korea (Korea DPR) and South-Korea (Korea Republic).

# %%
df.loc[df["Home Team Name"].str.contains('Korea',na=False), "Home Team Name" ]
# Out:
# 179         Korea DPR
# 187         Korea DPR
# 374    Korea Republic
# 386    Korea Republic
# 434    Korea Republic
# 444    Korea Republic
# 480    Korea Republic
# 524    Korea Republic
# 593    Korea Republic
# 609    Korea Republic
# 635    Korea Republic
# 642    Korea Republic
# 655    Korea Republic
# 710    Korea Republic
# 753         Korea DPR
# 802    Korea Republic
# 818    Korea Republic
# Name: Home Team Name, dtype: object

# %% [markdown]
# Imagine that for some reason, we simply want Korea listed as one entry, so we want to replace every "Home Team Name" and "Away Team Name" entry that contains "Korea" to simply "Korea". In the same way, we want to change the columns "Home Team Initials" and "Away Team Initials" to NSK (North & South Korea) instead of "KOR" and "PRK".

# %%
df.loc[df["Home Team Name"].str.contains('Korea',na=False), "Home Team Name"] = "Korea"
df.loc[df["Away Team Name"].str.contains('Korea',na=False), "Away Team Name"] = "Korea"
df.loc[df["Home Team Initials"].str.contains(('KOR' or 'PRK'),na=False), "Home Team Initials"] = "NSK"
df.loc[df["Away Team Initials"].str.contains(('KOR' or 'PRK'),na=False), "Away Team Initials"] = "NSK"

# %% [markdown]
# Make sure to verify your answer!

# %%
df.loc[df["Home Team Initials"].str.contains(('NSK'),na=False), "Home Team Initials"]
# Out:
# 179    NSK
# 187    NSK
# 374    NSK
# 386    NSK
# 434    NSK
# 444    NSK
# 480    NSK
# 524    NSK
# 593    NSK
# 609    NSK
# 635    NSK
# 642    NSK
# 655    NSK
# 710    NSK
# 753    NSK
# 802    NSK
# 818    NSK
# Name: Home Team Initials, dtype: object
